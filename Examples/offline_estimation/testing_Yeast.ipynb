# %%
from biomoni.Experiment import Experiment
from biomoni.Yeast import Yeast
from biomoni.Yeast_variable_feedrate import Yeast_vf
from biomoni.visualize import visualize

import pandas as pd
import numpy as np

# %load_ext autoreload
# %autoreload 2

#select your path to load the experiment/s
#Linux path
path = "/home/paul/pCloudDrive/Code/Messdaten" 

# #windows path
#path = r"P:\Code\biomoni\Messdaten"

# %%
# show stuff for class Experiment
a = Experiment(path, "F8", endpoint= "end2")
print(a.metadata)
a.dataset["on"]
# Out:
# start            2020-12-14 09:43:00
# end1             2020-12-14 18:20:00
# end2             2020-12-16 10:30:00
# tsfeedOn         2020-12-14 09:43:00
# feed_on                          0.0
# V0                               0.5
# mX0_wet                          3.4
# mX0                         0.914172
# cX0                         1.828343
# cS0                                2
# drymassfactor               0.268874
# mS0                              1.0
# feed_rate                     0.0069
# csf                              200
# gas_flow                          30
# T                                 32
# M_base                             5
# mE0                           0.0001
# feed_factor                  0.00276
# Name: F8, dtype: object
#                       PDatTime        Age      TEMP    JTEMP       STIRR  \
# t
# 0.037778   14.12.2020 09:45:16   0.000000  23.20500  33.8700  700.000000
# 0.121111   14.12.2020 09:50:16   0.083333  28.28625  39.6900  700.000000
# 0.204444   14.12.2020 09:55:16   0.166667  32.55000  30.9300  700.000000
# 0.287778   14.12.2020 10:00:16   0.250000  31.95000  32.6395  700.000000
# 0.371111   14.12.2020 10:05:16   0.333333  31.95000  32.4975  700.000000
# ...                        ...        ...       ...      ...         ...
# 48.371111  16.12.2020 10:05:16  48.333333  31.99500  31.6950  774.600000
# 48.454444  16.12.2020 10:10:16  48.416667  31.99500  31.6950  774.800000
# 48.537778  16.12.2020 10:15:16  48.500000  31.99500  31.7475  766.796667
# 48.621111  16.12.2020 10:20:16  48.583333  31.99500  31.7475  769.600000
# 48.704444  16.12.2020 10:25:16  48.666667  31.99500  31.6950  759.456667
#
#                  pH         pO2     AIRSP  MFC_B  MFC_C  ...  TURB     pHo  \
# t                                                        ...
# 0.037778   5.439000  102.530000  0.501150      0      0  ...     0 -0.0002
# 0.121111   5.364717   93.729750  0.500850      0      0  ...     0 -0.0002
# 0.204444   5.151275   77.682583  0.500550      0      0  ...     0 -0.0002
# 0.287778   5.195275   75.889417  0.500625      0      0  ...     0 -0.0002
# 0.371111   5.194017   73.574333  0.500775      0      0  ...     0 -0.0002
# ...             ...         ...       ...    ...    ...  ...   ...     ...
# 48.371111  5.217000   40.011500  0.500775      0      0  ...     0 -0.0002
# 48.454444  5.197942   40.350917  0.500850      0      0  ...     0 -0.0002
# 48.537778  5.183500   40.197167  0.500850      0      0  ...     0 -0.0002
# 48.621111  5.229767   40.053667  0.501000      0      0  ...     0 -0.0002
# 48.704444  5.254500   40.259167  0.501075      0      0  ...     0 -0.0002
#
#            pO2o  EO2  ECO2     AIROV  N2SP  CO2SP                  ts  \
# t
# 4.954444     0  0.500925     0      0 2020-12-14 14:40:16       0.757
# 5.037778     0  0.501000     0      0 2020-12-14 14:45:16       0.902
# 5.121111     0  0.501000     0      0 2020-12-14 14:50:16       0.813
# 5.204444     0  0.501225     0      0 2020-12-14 14:55:16       0.975
#
# [32 rows x 47 columns]

# %%
#show yeast class
y1 = Yeast()
print(y1)
print("\n\n")
print(y1.p)
print("\n\n")
print(y1.yields)
# Out:
# Yeast()
#
#
#
# Parameters([('qsmax', <Parameter 'qsmax', value=1.6, bounds=[0.01:5.0]>), ('qemax', <Parameter 'qemax', value=0.2361 (fixed), bounds=[0.15:0.35]>), ('base_coef', <Parameter 'base_coef', value=0.007395, bounds=[0.0001:3]>), ('qO2max', <Parameter 'qO2max', value=0.164745, bounds=[0.1:0.4]>), ('qm_max', <Parameter 'qm_max', value=0.01 (fixed), bounds=[0.0075:0.0125]>), ('Ks', <Parameter 'Ks', value=0.1 (fixed), bounds=[0.01:1]>), ('Ke', <Parameter 'Ke', value=0.1 (fixed), bounds=[0.01:1]>), ('Ki', <Parameter 'Ki', value=0.1 (fixed), bounds=[0.01:1]>), ('Yxs_ox', <Parameter 'Yxs_ox', value=0.5389, bounds=[0.3:0.6]>), ('Yxs_red', <Parameter 'Yxs_red', value=0.05 (fixed), bounds=[0.01:0.8]>), ('Yxe_et', <Parameter 'Yxe_et', value=0.72 (fixed), bounds=[0.5:0.8]>), ('Yxg_glyc', <Parameter 'Yxg_glyc', value=0.2 (fixed), bounds=[0.1:0.35]>), ('HX', <Parameter 'HX', value=1.79 (fixed), bounds=[1.77:2.1]>), ('OX', <Parameter 'OX', value=0.57 (fixed), bounds=[0.54:0.63]>), ('NX', <Parameter 'NX', value=0.15 (fixed), bounds=[0.14:0.16]>), ('g_e', <Parameter 'g_e', value=0.21636282532087284 (fixed), bounds=[0.17624196916440354:0.2883951412907231]>)])
#
#
#
# {'Yxs_ox': 0.5389, 'Yxs_red': 0.05, 'Yxe_et': 0.72, 'Yxg_glyc': 0.2, 'YCO2x_ox': 0.961955683882316, 'YCO2s_ox': 0.5183979180441801, 'YO2s_ox': 0.3424776324452058, 'Yes_red': 0.4255007119184566, 'Ygs_red': 0.09206253620672007, 'YCO2x_red': 8.657426507211436, 'YCO2s_red': 0.4328713253605718, 'YCO2x_et': 0.895747180208026, 'YCO2e_et': 0.6449379697497786, 'YO2e_et': 1.117484895862111, 'YCO2x_glyc': 5.410263481360806, 'YCO2g_glyc': 1.0820526962721613, 'YO2g_glyc': 1.8944680961004408, 'YCO2s_m': 1.4657061593696088}

# %%
#Creating dict /list with several experiments and process some of them

experiment_dict = {exp : Experiment(path, exp) for exp in ["F4", "F5", "F6", "F7", "F8" ]}  #all experiments in a dictionary
experiment_dict["F8"].time_filter(dskey= "on", start = pd.to_datetime("14.12.2020  12:20:16")) #special time filter for experiment 8
[experiment_dict[exp].pop_dataframe("on") for exp in ["F4", "F5", "F6"]]   #delete online data in experiment 4,5,6 because of bad BASET_rate measurements
experiment_list = list(experiment_dict.values())

# %%
#instantiating yeast object from Yeast class
yeast = Yeast()

# %%
#Change fit parameters to arbitrary to emonstrate estimation. Value have to be within min, max
yeast.change_params("qsmax", value =1, max = 10)
yeast.change_params("base_coef", value = 1)
yeast.change_params("qO2max", value = 0.2)
yeast.change_params("Yxs_ox" , value = 0.4)
display(yeast.p)
# Out:
# Parameters([('qsmax', <Parameter 'qsmax', value=1, bounds=[0.01:10]>),
#             ('qemax',
#              <Parameter 'qemax', value=0.2361 (fixed), bounds=[0.15:0.35]>),
#             ('base_coef', <Parameter 'base_coef', value=1, bounds=[0.0001:3]>),
#             ('qO2max', <Parameter 'qO2max', value=0.2, bounds=[0.1:0.4]>),
#             ('qm_max',
#              <Parameter 'qm_max', value=0.01 (fixed), bounds=[0.0075:0.0125]>),
#             ('Ks', <Parameter 'Ks', value=0.1 (fixed), bounds=[0.01:1]>),
#             ('Ke', <Parameter 'Ke', value=0.1 (fixed), bounds=[0.01:1]>),
#             ('Ki', <Parameter 'Ki', value=0.1 (fixed), bounds=[0.01:1]>),
#             ('Yxs_ox', <Parameter 'Yxs_ox', value=0.4, bounds=[0.3:0.6]>),
#             ('Yxs_red',
#              <Parameter 'Yxs_red', value=0.05 (fixed), bounds=[0.01:0.8]>),
#             ('Yxe_et',
#              <Parameter 'Yxe_et', value=0.72 (fixed), bounds=[0.5:0.8]>),
#             ('Yxg_glyc',
#              <Parameter 'Yxg_glyc', value=0.2 (fixed), bounds=[0.1:0.35]>),
#             ('HX', <Parameter 'HX', value=1.79 (fixed), bounds=[1.77:2.1]>),
#             ('OX', <Parameter 'OX', value=0.57 (fixed), bounds=[0.54:0.63]>),
#             ('NX', <Parameter 'NX', value=0.15 (fixed), bounds=[0.14:0.16]>),
#             ('g_e',
#              <Parameter 'g_e', value=0.21636282532087284 (fixed), bounds=[0.17624196916440354:0.2883951412907231]>)])

# %%
#estimate parameters for given experiments in the list: You can give a list or dict of experiments or a single experiment
yeast.estimate(experiment_dict)     #it is possible to hand over a dict, a list (experiment_list for example) or a single experiment, it is also possible to hand over kwargs for solve_ivp in form of a dict and kwargs fpr lmfit.minimize , kwargs_solve_ivp = dict(method= "RK23", first_step = 0.0000001, max_step= 0.1), gtol = 0.1
##possible example  kwags arguments: max_nfev = 100, gtol = 0.1, xtol= 0.1

# %%
#show fit statistics
yeast.report()
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 74
#     # data points      = 2600
#     # variables        = 4
#     chi-square         = 46.3684826
#     reduced chi-square = 0.01786151
#     Akaike info crit   = -10461.2815
#     Bayesian info crit = -10437.8285
# [[Variables]]
#     qsmax:      1.59979096 +/- 0.00482125 (0.30%) (init = 1)
#     qemax:      0.2361 (fixed)
#     base_coef:  0.00739355 +/- 3.2688e-04 (4.42%) (init = 1)
#     qO2max:     0.16469731 +/- 0.00212846 (1.29%) (init = 0.2)
#     qm_max:     0.01 (fixed)
#     Ks:         0.1 (fixed)
#     Ke:         0.1 (fixed)
#     Ki:         0.1 (fixed)
#     Yxs_ox:     0.53892767 +/- 0.00222314 (0.41%) (init = 0.4)
#     Yxs_red:    0.05 (fixed)
#     Yxe_et:     0.72 (fixed)
#     Yxg_glyc:   0.2 (fixed)
#     HX:         1.79 (fixed)
#     OX:         0.57 (fixed)
#     NX:         0.15 (fixed)
#     g_e:        0.2163628 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(qO2max, Yxs_ox) = -0.998
#     C(qsmax, Yxs_ox)  = -0.303
#     C(qsmax, qO2max)  =  0.246

# %%
display(yeast.p)
# Out:
# Parameters([('qsmax',
#              <Parameter 'qsmax', value=1.5997909638766399 +/- 0.00482, bounds=[0.01:10]>),
#             ('qemax',
#              <Parameter 'qemax', value=0.2361 (fixed), bounds=[0.15:0.35]>),
#             ('base_coef',
#              <Parameter 'base_coef', value=0.007393552021408298 +/- 0.000327, bounds=[0.0001:3]>),
#             ('qO2max',
#              <Parameter 'qO2max', value=0.16469730774680258 +/- 0.00213, bounds=[0.1:0.4]>),
#             ('qm_max',
#              <Parameter 'qm_max', value=0.01 (fixed), bounds=[0.0075:0.0125]>),
#             ('Ks', <Parameter 'Ks', value=0.1 (fixed), bounds=[0.01:1]>),
#             ('Ke', <Parameter 'Ke', value=0.1 (fixed), bounds=[0.01:1]>),
#             ('Ki', <Parameter 'Ki', value=0.1 (fixed), bounds=[0.01:1]>),
#             ('Yxs_ox',
#              <Parameter 'Yxs_ox', value=0.5389276716799172 +/- 0.00222, bounds=[0.3:0.6]>),
#             ('Yxs_red',
#              <Parameter 'Yxs_red', value=0.05 (fixed), bounds=[0.01:0.8]>),
#             ('Yxe_et',
#              <Parameter 'Yxe_et', value=0.72 (fixed), bounds=[0.5:0.8]>),
#             ('Yxg_glyc',
#              <Parameter 'Yxg_glyc', value=0.2 (fixed), bounds=[0.1:0.35]>),
#             ('HX', <Parameter 'HX', value=1.79 (fixed), bounds=[1.77:2.1]>),
#             ('OX', <Parameter 'OX', value=0.57 (fixed), bounds=[0.54:0.63]>),
#             ('NX', <Parameter 'NX', value=0.15 (fixed), bounds=[0.14:0.16]>),
#             ('g_e',
#              <Parameter 'g_e', value=0.21636282532087284 (fixed), bounds=[0.17624196916440354:0.2883951412907231]>)])

# %%
y2 = Yeast_vf()
t_grid = np.linspace(0,9,1000)

# %%
y2.simulate(a, endpoint = "end2")
# Out:
#                   V         cX        cS            cE  BASET_rate       CO2
# t
# 0.000000   0.500000   1.828343  2.000000  2.000000e-04    0.398076  1.262799
# 0.048832   0.500337   1.853777  1.995295  4.091991e-02    0.403874  1.281096
# 0.097664   0.500674   1.879565  1.988602  8.217076e-02    0.409751  1.299600
# 0.146496   0.501011   1.905711  1.979904  1.239569e-01    0.415708  1.318311
# 0.195329   0.501348   1.932220  1.969182  1.662826e-01    0.421745  1.337226
# ...             ...        ...       ...           ...         ...       ...
# 48.588005  0.835257  38.281701  0.002749  6.908363e-27    0.821472  1.982999
# 48.636837  0.835594  38.298971  0.002747 -1.091185e-27    0.821260  1.983483
# 48.685669  0.835931  38.316219  0.002745 -1.171912e-26    0.821049  1.983967
# 48.734501  0.836268  38.333445  0.002742 -8.034835e-26    0.820837  1.984451
# 48.783333  0.836605  38.350648  0.002740 -3.358293e-26    0.820625  1.984935
#
# [1000 rows x 6 columns]

# %%
#simulate one single experiment in combination with its simulation (with estimated params)
# Data should be given either as an Experiment, a pd.DataFrame or as a list or dict with pd.DataFrame objects
a = Experiment(path, "F7")
o = yeast.simulate(a)          #max_step =10, method = "BDF", rtol = 10
visualize(a, o, suffix_1 = "_exp", suffix_2 = "_fitted", title = "Fermentation 7").show()
# Out:
# hi

# %%
#Get datasets of experiments and simulate for each expriment, save both in seperate dictionaries
#it is necessary to estimate beforehand (yeast.estimate) for good simulation results, because yeast.p takes on the estimated params after estimation
t_grid = np.linspace(0,9,1001)      #artificial t_grid

sim_dict_all = {experiment.exp_id: yeast.simulate(experiment = experiment, t_grid = t_grid) for experiment in experiment_dict.values()}
#experiment_dataset_dict_all = {experiment.exp_id: experiment.dataset for experiment in experiment_dict.values()} # also possible to give

#visualize experiments and simulated data simultaneously
for exp_id  in experiment_dict.keys():
    title = "Experiment {0}".format(exp_id) 
    visualize(experiment_dict[exp_id] , sim_dict_all[exp_id], title = title, suffix_1= "_experimental", suffix_2 = "_fitted").show()

# %%
#For Valeria with a variable feedrate
y_vf = Yeast_vf()
y_vf.estimate(experiment_dict)
y_vf.report()
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 138
#     # data points      = 2600
#     # variables        = 4
#     chi-square         = 46.0183230
#     reduced chi-square = 0.01772663
#     Akaike info crit   = -10480.9904
#     Bayesian info crit = -10457.5373
# [[Variables]]
#     qsmax:      1.58685755 +/- 0.00462709 (0.29%) (init = 1.612905)
#     qemax:      0.2361 (fixed)
#     base_coef:  0.00739127 +/- 3.2580e-04 (4.41%) (init = 0.00733798)
#     qO2max:     0.16064993 +/- 4.2522e-04 (0.26%) (init = 0.1647364)
#     qm_max:     0.01 (fixed)
#     Ks:         0.1 (fixed)
#     Ke:         0.1 (fixed)
#     Ki:         0.1 (fixed)
#     Yxs_ox:     0.54322789 +/- 4.1711e-04 (0.08%) (init = 0.5279213)
#     Yxs_red:    0.05 (fixed)
#     Yxe_et:     0.72 (fixed)
#     Yxg_glyc:   0.2 (fixed)
#     HX:         1.79 (fixed)
#     OX:         0.57 (fixed)
#     NX:         0.15 (fixed)
#     g_e:        0.2163628 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(qsmax, Yxs_ox)  = -1.000
#     C(qsmax, qO2max)  =  0.581
#     C(qO2max, Yxs_ox) = -0.581
